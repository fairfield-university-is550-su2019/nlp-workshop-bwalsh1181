# %% [markdown]
# # NATURAL LANGUAGE PROCESSING WITH TEXTACY & SPACY
#
# __Spacy__ is a very high performance NLP library for doing several tasks of NLP with ease and speed. Let us explore another library built on top of __SpaCy__ called __TextaCy__.
#
# ## TEXTACY
# + Textacy is a Python library for performing higher-level natural language processing (NLP) tasks,
# built on the high-performance Spacy library.
# + Textacy focuses on tasks facilitated by the availability of tokenized, POS-tagged, and parsed text.
# + Uses
#     + Text preprocessing
#     + Keyword in Context
#     + Topic modeling
#     + Information Extraction
#     + Keyterm extraction,
#     + Text and Readability statistics,
#     + Emotional valence analysis,
#     + Quotation attribution
#
# ### INSTALLATION
# You can install using `pip install textacy` or `conda install -c conda-forge textacy`.
# NB: In case you are having issues with installing on windows you can use conda instead of pip.
#
# ### Downloading Dataset
# You can use the following command to download the `capitol_words` dataset, whcih we will use in this tutorial.
# `python -m textacy download capital_words`
#
# ### FOR LANGUAGE DETECTION
# You can either use `pip install textacy[lang]` or `pip install cld2-cffi` to install the required language pack for textacy.
#
# __NOTE__: All required the package, dependencies, and add-on packs are pre-installed for this tutorial.
#
# ## Getting Started

# %%
# Loading Packages
import textacy

##another good library (good with Sentance tokenization)
# nltk --> good library for this

# %%
example = "Textacy is a Python library for performing higher-level natural language processing (NLP) tasks, \
built on the high-performance Spacy library. With the basics — tokenization, part-of-speech tagging, parsing \
— offloaded to another library, textacy focuses on tasks facilitated by the availability of tokenized, POS-tagged, \
and parsed text: keyterm extraction, readability statistics, emotional valence analysis, quotation attribution, \
and more."

# %%
example
# Out:
# 'Textacy is a Python library for performing higher-level natural language processing (NLP) tasks, built on the high-performance Spacy library. With the basics — tokenization, part-of-speech tagging, parsing — offloaded to another library, textacy focuses on tasks facilitated by the availability of tokenized, POS-tagged, and parsed text: keyterm extraction, readability statistics, emotional valence analysis, quotation attribution, and more.'

# %% [markdown]
# ## TEXT PREPROCESSING WITH TEXTACY
# Following methods can be used to preprocess your text data:
#
# + `textacy.preprocess_text()`
# + `textacy.preprocess.`
#     + Punctuation Lowercase
#     + Urls
#     + Phone numbers
#     + Currency
#     + Emails

# %%
raw_text = """ The best programs, are the ones written when the programmer is supposed to be working on something else.\
Mike bought the book for $50 although in Paris it will cost $30 dollars. Don’t document the problem, \
fix it.This is from https://twitter.com/codewisdom?lang=en. """

# %%
# Removing Punctuation and Uppercase
processed_text = textacy.preprocess.remove_punct(raw_text)
processed_text
# Out:
# ' The best programs  are the ones written when the programmer is supposed to be working on something else Mike bought the book for $50 although in Paris it will cost $30 dollars  Don t document the problem  fix it This is from https   twitter com codewisdom lang=en  '

# %%
# Removing urls
processed_text = textacy.preprocess.replace_urls(raw_text,replace_with='TWITTER')
processed_text
# Out:
# ' The best programs, are the ones written when the programmer is supposed to be working on something else.Mike bought the book for $50 although in Paris it will cost $30 dollars. Don’t document the problem, fix it.This is from TWITTER '

# %%
# Replacing Currency Symbols
processed_text = textacy.preprocess.replace_currency_symbols(processed_text,replace_with='USD')
processed_text
# Out:
# ' The best programs, are the ones written when the programmer is supposed to be working on something else.Mike bought the book for USD50 although in Paris it will cost USD30 dollars. Don’t document the problem, fix it.This is from TWITTER '

# %% [markdown]
# Notice that we created a variable `processed_text` in every cell block above? That is because that usually text preprocessing is a pipeline - with multiple steps in it. Here are the steps we completed above:
# + Removing Punctuation and Uppercase
# + Removing urls
# + Replacing Currency Symbols
#
# So we are using the variable to pass text data from each step to the next.
#
# There are much more text preprocessing steps. [Here](https://www.kdnuggets.com/2019/04/text-preprocessing-nlp-machine-learning.html) is a good summary of these steps.
#
# You can incorporate all above steps together using the following code:

# %% [markdown]
# ** Note: when preprocessing data, start wuth the step that has the smallest span **

# %%
#Corrected Sequence
processed_text = textacy.preprocess.replace_currency_symbols(raw_text,replace_with='USD')
processed_text = textacy.preprocess.replace_urls(processed_text,replace_with='TWITTER')
processed_text = textacy.preprocess.remove_punct(processed_text)
processed_text
# Out:
# ' The best programs  are the ones written when the programmer is supposed to be working on something else Mike bought the book for USD50 although in Paris it will cost USD30 dollars  Don t document the problem  fix it This is from TWITTER '

# %%
# Preprocess All
processed_text = textacy.preprocess_text(raw_text,lowercase=True,no_punct=True,no_urls=True,no_currency_symbols=True)
processed_text
# Out:
# 'the best programs are the ones written when the programmer is supposed to be working on something else mike bought the book for usd50 although in paris it will cost usd30 dollars don t document the problem fix it this is from url'

# %% [markdown]
# ## SHIFT + TAB inside of the code method will bring up documentation on it

# %% [markdown]
# ** The Most important first step is to identify which pipeline steps have a logical dependency on the others, and start with the least impactful **

# %% [markdown]
# Refer to the [docs](https://chartbeat-labs.github.io/textacy/api_reference.html#module-textacy.preprocess) for more details of the `textacy.preprocess` and its family methods.
#
# ### READING A TEXT OR A DOCUMENT
# + `textacy.Doc(your_text)`
# + `textacy.io.read_text(your_text)`
#
# Textacy would not receive a lot of attractions if it only can remove URLs or punctuations; however, all additional/more advanced techniques/analyses required on `formatting` the data.
#
# TextaCy/SpaCy uses a `Doc` as a container for any text objects. [Here](https://chartbeat-labs.github.io/textacy/getting_started/quickstart.html#make-a-doc) is nice documentation of the `doc` object.

# %% [markdown]
# ** DOC is a any sort of processed text, NOT necisarily a document [it can be a single character even]

# %%
# With Doc
# Requires Language Pkg Model
docx_textacy = textacy.Doc(example, lang='en')

# %%
docx_textacy
# Out:
# Doc(82 tokens; "Textacy is a Python library for performing high...")

# %% [markdown]
# ** A token is a character. Includes punctuation and spaces and all of that stuff **

# %% [markdown]
# We can look at the `type` of the `docx_textacy` object.

# %%
type(docx_textacy)
# Out:
# textacy.doc.Doc

# %% [markdown]
# Following code read a `doc` from a local file:
#
# 1. use the .read() method
# `file_textacy = textacy.Doc(open("example.txt").read())`
#
# 2. create a generator
# `file_textacy2 = textacy.io.read_text('example.txt',lines=True)`
#
# then:
#
# `for text in file_textacy2:`
#
#     `docx_file = textacy.Doc(text)`
#
#     `print(docx_file)`

# %% [markdown]
# ### Advanced Text Analytics
#
# 1. Named-Entity Recognition
#
# Named-entity recognition (NER) (also known as entity identification, entity chunking and entity extraction) is a subtask of information extraction that seeks to locate and classify named entity mentions in unstructured text into pre-defined categories such as the person names, organizations, locations, medical codes, time expressions, quantities, monetary values, percentages, etc. [Source: [Wikipedia](https://en.wikipedia.org/wiki/Named-entity_recognition)]
#
# TextaCy has a built-in method for NER.

# %%
# Using Textacy Named Entity Extraction
list(textacy.extract.named_entities(docx_textacy))
# Out:
# [NLP, Spacy]

# %% [markdown]
# 2. n-grams
#
# In the fields of computational linguistics and probability, an n-gram is a contiguous sequence of n items from a given sample of text or speech. The items can be phonemes, syllables, letters, words or base pairs according to the application. The n-grams typically are collected from a text or speech corpus. When the items are words, n-grams may also be called shingles.
#
# TextaCy has a built-in method for n-grams.
#
# N-grams, a.k.a __Bag-of-Words__, is a very important quantifying approach for text data.

# %% [markdown]
# ** NGram will prefilter the results, we can tell it not to **

# %%
# NGrams with Textacy
# NB SpaCy method would be to use noun Phrases
# Tri Grams

list(textacy.extract.ngrams(docx_textacy,3))
# Out:
# [library for performing,
#  level natural language,
#  natural language processing,
#  performance Spacy library,
#  With the basics,
#  focuses on tasks,
#  availability of tokenized,
#  emotional valence analysis]

# %% [markdown]
# 3. text statistics
# This usually includes computing basic counts and various readability statistics.

# %%
ts = textacy.TextStats(docx_textacy)

# %%
# Number of unique words
ts.n_unique_words
# Out:
# 51

# %%
# Basic counts of linguistic units
ts.basic_counts
# Out:
# {'n_sents': 2,
#  'n_words': 60,
#  'n_chars': 364,
#  'n_syllables': 116,
#  'n_unique_words': 51,
#  'n_long_words': 28,
#  'n_monosyllable_words': 29,
#  'n_polysyllable_words': 19}

# %%
# readability scores
ts.readability_stats
# Out:
# {'flesch_kincaid_grade_level': 18.923333333333336,
#  'flesch_reading_ease': 12.825000000000045,
#  'smog_index': 20.736966565827903,
#  'gunning_fog_index': 24.66666666666667,
#  'coleman_liau_index': 18.884049400000002,
#  'automated_readability_index': 22.144,
#  'lix': 76.66666666666666,
#  'gulpease_index': 38.333333333333336,
#  'wiener_sachtextformel': 14.740666666666666}

# %% [markdown]
# Some of these basic counts and readability stats seem intimidating. Feel free to Google them to better understand them.
#
# 4. Dealing with a collection of documents (corpus)
#
# Many NLP tasks require datasets comprised of a large number of texts, which are often stored on disk in one or multiple files. textacy makes it easy to efficiently stream text and (text, metadata) pairs from disk, regardless of the format or compression of the data.

# %%
import textacy.datasets  # note the import
ds = textacy.datasets.CapitolWords()
ds.download()
records = ds.records(speaker_name={"Hillary Clinton", "Barack Obama"})
next(records)
# Out:
# {'date': '2001-02-13',
#  'congress': 107,
#  'speaker_name': 'Hillary Clinton',
#  'speaker_party': 'D',
#  'title': 'MORNING BUSINESS',
#  'text': 'I yield myself 15 minutes of the time controlled by the Democrats.',
#  'chamber': 'Senate'}

# %% [markdown]
# A `textacy.Corpus` is an ordered collection of spaCy Doc s, all processed by the same language pipeline. Let’s continue with the Capitol Words dataset and make a corpus from a stream of records. (Note: This may take a few minutes.)

# %%
cw = textacy.datasets.CapitolWords()
records = cw.records(limit=100)
text_stream, metadata_stream = textacy.io.split_records(records, 'text')
corpus = textacy.Corpus('en', texts=text_stream, metadatas=metadata_stream)
print(corpus)
# Out:
# Corpus(100 docs; 70500 tokens)

# %%
for doc in corpus:
    print(doc.metadata.get("speaker_name"))
# Out:
# Bernie Sanders
# Lindsey Graham
# Bernie Sanders
# Bernie Sanders
# Rick Santorum
# Rick Santorum
# Bernie Sanders
# Bernie Sanders
# Bernie Sanders
# Bernie Sanders
# Bernie Sanders
# Rick Santorum
# Rick Santorum
# Rick Santorum
# Joseph Biden
# Bernie Sanders
# Joseph Biden
# Joseph Biden
# Bernie Sanders
# Rick Santorum
# Rick Santorum
# John Kasich
# John Kasich
# Lindsey Graham
# Lindsey Graham
# Lindsey Graham
# Lindsey Graham
# Bernie Sanders
# Rick Santorum
# Rick Santorum
# Joseph Biden
# Lindsey Graham
# Rick Santorum
# Bernie Sanders
# Rick Santorum
# Rick Santorum
# Rick Santorum
# Rick Santorum
# Lindsey Graham
# Lindsey Graham
# Lindsey Graham
# Joseph Biden
# Joseph Biden
# Rick Santorum
# Bernie Sanders
# Bernie Sanders
# Bernie Sanders
# John Kasich
# John Kasich
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Rick Santorum
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Lindsey Graham
# Lindsey Graham
# Lindsey Graham
# Lindsey Graham
# Bernie Sanders
# Rick Santorum
# Rick Santorum
# John Kasich
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Rick Santorum
# John Kasich
# Joseph Biden
# John Kasich
# John Kasich
# John Kasich
# John Kasich
# John Kasich
# John Kasich
# John Kasich
# John Kasich
# John Kasich
# John Kasich
# John Kasich
# Joseph Biden
# Joseph Biden
# Joseph Biden
# Bernie Sanders
# Bernie Sanders
# John Kasich
# Joseph Biden

# %% [markdown]
# You can filter the corpus using certain conditions, which would cover your specific use cases:

# %%
# Suppose we just want speeches of Mr. Bernie Sanders
# Just print out top-3 for illustration
match_func = lambda doc: doc.metadata.get("speaker_name") == "Bernie Sanders"

for doc in corpus.get(match_func, limit=3):
    print(doc)
# Out:
# Doc(159 tokens; "Mr. Speaker, 480,000 Federal employees are work...")
# Doc(336 tokens; "Mr. Speaker, I thank the gentleman for yielding...")
# Doc(177 tokens; "Mr. Speaker, if we want to understand why in th...")

# %% [markdown]
# Corpus is a list-like object that can be iterated on - each element in Corpus is a `textacy.Doc` object.
#
# Which means we can do slicing as we slice any list in Python:

# %%
# any element
corpus[0]
# Out:
# Doc(159 tokens; "Mr. Speaker, 480,000 Federal employees are work...")

# %%
# a sub-list
[doc for doc in corpus[:3]]
# Out:
# [Doc(159 tokens; "Mr. Speaker, 480,000 Federal employees are work..."),
#  Doc(219 tokens; "Mr. Speaker, a relationship, to work and surviv..."),
#  Doc(336 tokens; "Mr. Speaker, I thank the gentleman for yielding...")]

# %%
# You can delete elements from `corpus`
del corpus[:10]
corpus
# Out:
# Corpus(90 docs; 67161 tokens)

# %% [markdown]
# We can also get basic statistics of the `corpus` object:

# %%
corpus.n_docs, corpus.n_sents, corpus.n_tokens
# Out:
# (90, 2943, 67161)

# %%
# Word Counts - as a dictionary
counts = corpus.word_freqs(weighting='count', as_strings=True)

# %%
# we can get the top-5 frequent words form the `counts` dictionary
sorted(counts.items(), key=lambda x: x[1], reverse=True)[:5]
# Out:
# [('-PRON-', 4726),
#  ('people', 241),
#  ('mr.', 240),
#  ('president', 216),
#  ('bill', 209)]

# %% [markdown]
# We also introduce a new text metric called __term frequency - inversed document frequency__ (`tf-idf`).
#
# In information retrieval, tf–idf or TFIDF, short for term frequency–inverse document frequency, is a numerical statistic that is intended to reflect how important a word is to a document in a collection or corpus. It is often used as a weighting factor in searches of information retrieval, text mining, and user modeling. The tf–idf value increases proportionally to the number of times a word appears in the document and is offset by the number of documents in the corpus that contain the word, which helps to adjust for the fact that some words appear more frequently in general. tf–idf is one of the most popular term-weighting schemes today; 83% of text-based recommender systems in digital libraries use tf–idf.[Source: Wikipedia](https://en.wikipedia.org/wiki/Tf%E2%80%93idf).
#
# Term frequency (`tf`) in `tf-idf` is the word frequency we get from above dictionary (`counts`). Now we need to calculate the `idf` part.
#
# The inverse document frequency is a measure of how much information the word provides, i.e., if it's common or rare across all documents. It is the logarithmically scaled inverse fraction of the documents that contain the word (obtained by dividing the total number of documents by the number of documents containing the term, and then taking the logarithm of that quotient):

# %% [markdown]
# \begin{equation*}
# idf(t, D) = log(\frac{N_D}{N_t})
# \end{equation*}
#
# In which, $ N_D $ is the number of documents (`doc`) in `corpus` D; and $ N_t $ is the number of `doc`s in $ D $ containing term $ t $.
#
# Looks complicated, right? Fortunately we can use TextaCy's built-in methods to calculate `idf`.

# %%
idf = corpus.word_doc_freqs(as_strings=True, weighting='idf')

# %%
sorted(idf.items(), key=lambda x: x[1], reverse=True)[:5]
# Out:
# [('355', 4.51085950651685),
#  ('absent', 4.51085950651685),
#  ('unavoidably', 4.51085950651685),
#  ('ordering', 4.51085950651685),
#  ('con', 4.51085950651685)]

# %% [markdown]
# Since now we have both __tf__ as a dict object `counts`; and idf as a dict object `idf`, we can calculate the complete __tf-idf__ metric.

# %%
tf_idf = {k: counts[k]/idf[k] for k in idf.keys() & counts}

# %% [markdown]
# ### YOUR TURN HERE
#
# Please print out the top-20 terms with the highest `tf-idf` values.

# %%
#### Complete your code here
sorted(tf_idf.items(), key=lambda x: x[1], reverse=True)[:20]
# Out:
# [('-PRON-', 6654.073638294795),
#  ('mr.', 295.9564154851718),
#  ('president', 222.81811001485437),
#  ('people', 204.4703503128777),
#  ('year', 172.23021208927045),
#  ('bill', 172.09519917661507),
#  ('think', 126.47630887391287),
#  ("'s", 121.62794885731749),
#  ('work', 118.93710442204127),
#  ('american', 106.85316269251574),
#  ('know', 102.90929479802848),
#  ('$', 99.25286446516297),
#  ('money', 92.74811562385676),
#  ('good', 92.7279409085042),
#  ('want', 90.44774564026228),
#  ('time', 88.60415161642001),
#  ('federal', 84.80466267593039),
#  ('let', 83.60715983553656),
#  ('percent', 79.19058576140583),
#  ('state', 77.65646307702684)]

# %% [markdown]
# Some of above results make sense, such as 'president' and 'bill' and 'act'. But terms like '-PRON-' (referring to pronouns such as 'you' or 'I') and ''s' do not make sense. Similar conclusion can be drawn onto words such as 'a', 'an', 'the', ...
#
# These words are called __stop words__. In computing, stop words are words which are filtered out before or after processing of natural language data (text). Though "stop words" usually refers to the most common words in a language, there is no single universal list of stop words used by all natural language processing tools, and indeed not all tools even use such a list. Some tools specifically avoid removing these stop words to support phrase search. [Source: Wikipedia](https://en.wikipedia.org/wiki/Stop_words).
#
# We can check if a word (a.k.a. token) is stop by using the `is_stop` attribute provided with `textacy.token` object.

# %%
my_doc = corpus[0]

for t in my_doc.tokens:
    print(t, t.is_stop)
# Out:
# Mr. False
# Speaker False
# , False
# I False
# was True
# unavoidably False
# absent False
# during True
# the True
# votes False
# on True
# default False
# legislation False
# . False
# If False
# I False
# had True
# been True
# present False
# , False
# I False
# would True
# have True
# voted False
# " False
# nay False
# " False
# on True
# the True
# motions False
# to True
# table False
# the True
# appeal False
# of True
# the True
# ruling False
# of True
# the True
# Chair False
# with True
# regards False
# to True
# the True
# resolutions False
# offered False
# by True
# Mr. False
# Gephardt False
# ( False
# rollcall False
# No False
# . False
# 26 False
# ) False
# and True
# Ms. False
# Jackson False
# - False
# Lee False
# ( False
# rollcall False
# No False
# . False
# 27 False
# ) False
# , False
# I False
# would True
# have True
# voted False
# " False
# nay False
# " False
# on True
# the True
# ordering False
# of True
# the True
# previous False
# question False
# on True
# House False
# Resolution False
# 355 False
# ( False
# rollcall False
# No False
# . False
# 28 False
# ) False
# . False
# I False
# would True
# have True
# voted False
# " False
# nay False
# " False
# on True
# H. False
# Con False
# . False
# Res False
# . False
# 141 False
# ( False
# rollcall False
# No False
# . False
# 29 False
# ) False
# . False
# I False
# would True
# have True
# voted False
# " False
# yea False
# " False
# on True
# H.R. False
# 2924 False
# ( False
# rollcall False
# No False
# . False
# 30 False
# ) False
# . False

# %% [markdown]
# ### YOUR TURN HERE
#
# Remove all stop words from `my_doc`.
#
# __HINT__: using an `if` statement (with the `is_stop` attribute) in the `for` loop.

# %%
#### Complete your code here
## This is MY WAY

for t in my_doc.tokens:
    if t.is_stop == False:
        print(t, t.is_stop)
# Out:
# Mr. False
# Speaker False
# , False
# I False
# unavoidably False
# absent False
# votes False
# default False
# legislation False
# . False
# If False
# I False
# present False
# , False
# I False
# voted False
# " False
# nay False
# " False
# motions False
# table False
# appeal False
# ruling False
# Chair False
# regards False
# resolutions False
# offered False
# Mr. False
# Gephardt False
# ( False
# rollcall False
# No False
# . False
# 26 False
# ) False
# Ms. False
# Jackson False
# - False
# Lee False
# ( False
# rollcall False
# No False
# . False
# 27 False
# ) False
# , False
# I False
# voted False
# " False
# nay False
# " False
# ordering False
# previous False
# question False
# House False
# Resolution False
# 355 False
# ( False
# rollcall False
# No False
# . False
# 28 False
# ) False
# . False
# I False
# voted False
# " False
# nay False
# " False
# H. False
# Con False
# . False
# Res False
# . False
# 141 False
# ( False
# rollcall False
# No False
# . False
# 29 False
# ) False
# . False
# I False
# voted False
# " False
# yea False
# " False
# H.R. False
# 2924 False
# ( False
# rollcall False
# No False
# . False
# 30 False
# ) False
# . False

# %%
## This Is correct way of above code
[t for t in my_doc.tokens if (not t.is_stop)]
# Out:
# [Mr.,
#  Speaker,
#  ,,
#  I,
#  unavoidably,
#  absent,
#  votes,
#  default,
#  legislation,
#  .,
#  If,
#  I,
#  present,
#  ,,
#  I,
#  voted,
#  ",
#  nay,
#  ",
#  motions,
#  table,
#  appeal,
#  ruling,
#  Chair,
#  regards,
#  resolutions,
#  offered,
#  Mr.,
#  Gephardt,
#  (,
#  rollcall,
#  No,
#  .,
#  26,
#  ),
#  Ms.,
#  Jackson,
#  -,
#  Lee,
#  (,
#  rollcall,
#  No,
#  .,
#  27,
#  ),
#  ,,
#  I,
#  voted,
#  ",
#  nay,
#  ",
#  ordering,
#  previous,
#  question,
#  House,
#  Resolution,
#  355,
#  (,
#  rollcall,
#  No,
#  .,
#  28,
#  ),
#  .,
#  I,
#  voted,
#  ",
#  nay,
#  ",
#  H.,
#  Con,
#  .,
#  Res,
#  .,
#  141,
#  (,
#  rollcall,
#  No,
#  .,
#  29,
#  ),
#  .,
#  I,
#  voted,
#  ",
#  yea,
#  ",
#  H.R.,
#  2924,
#  (,
#  rollcall,
#  No,
#  .,
#  30,
#  ),
#  .]

# %% [markdown]
# Sometimes we only care about __word tokens__, which means we need to filter out _numbers_, _punctuations_, and so forth.
#
# TextaCy provides a `is_alpha` attribute for that purpose.

# %%
for t in my_doc.tokens:
    print(t, t.is_alpha)
# Out:
# Mr. False
# Speaker True
# , False
# I True
# was True
# unavoidably True
# absent True
# during True
# the True
# votes True
# on True
# default True
# legislation True
# . False
# If True
# I True
# had True
# been True
# present True
# , False
# I True
# would True
# have True
# voted True
# " False
# nay True
# " False
# on True
# the True
# motions True
# to True
# table True
# the True
# appeal True
# of True
# the True
# ruling True
# of True
# the True
# Chair True
# with True
# regards True
# to True
# the True
# resolutions True
# offered True
# by True
# Mr. False
# Gephardt True
# ( False
# rollcall True
# No True
# . False
# 26 False
# ) False
# and True
# Ms. False
# Jackson True
# - False
# Lee True
# ( False
# rollcall True
# No True
# . False
# 27 False
# ) False
# , False
# I True
# would True
# have True
# voted True
# " False
# nay True
# " False
# on True
# the True
# ordering True
# of True
# the True
# previous True
# question True
# on True
# House True
# Resolution True
# 355 False
# ( False
# rollcall True
# No True
# . False
# 28 False
# ) False
# . False
# I True
# would True
# have True
# voted True
# " False
# nay True
# " False
# on True
# H. False
# Con True
# . False
# Res True
# . False
# 141 False
# ( False
# rollcall True
# No True
# . False
# 29 False
# ) False
# . False
# I True
# would True
# have True
# voted True
# " False
# yea True
# " False
# on True
# H.R. False
# 2924 False
# ( False
# rollcall True
# No True
# . False
# 30 False
# ) False
# . False

# %% [markdown]
# ### YOUR TURN HERE
#
# What if we want non-stop and word tokens?
#
# __HINT__: combine the two above steps together.

# %%
#### Complete you code here
## This Is correct way of above code
[t for t in my_doc.tokens if ((not t.is_stop) and (t.is_alpha))]
# Out:
# [Speaker,
#  I,
#  unavoidably,
#  absent,
#  votes,
#  default,
#  legislation,
#  If,
#  I,
#  present,
#  I,
#  voted,
#  nay,
#  motions,
#  table,
#  appeal,
#  ruling,
#  Chair,
#  regards,
#  resolutions,
#  offered,
#  Gephardt,
#  rollcall,
#  No,
#  Jackson,
#  Lee,
#  rollcall,
#  No,
#  I,
#  voted,
#  nay,
#  ordering,
#  previous,
#  question,
#  House,
#  Resolution,
#  rollcall,
#  No,
#  I,
#  voted,
#  nay,
#  Con,
#  Res,
#  rollcall,
#  No,
#  I,
#  voted,
#  yea,
#  rollcall,
#  No]

# %% [markdown]
# From the results, have you noticed that different forms of the same token may appear in the text? For instance, 'run', 'ran', and 'running' are all different forms of the root word 'run'. Counting them as different words may bias any subsequent model. Thus, it would be ideal to make different forms of the same word to the root. This process is called __lemmatization__.
#
# _Lemmatization_ usually refers to doing things properly with the use of a vocabulary and morphological analysis of words, normally aiming to remove inflectional endings only and to return the base or dictionary form of a word, which is known as the _lemma_. If confronted with the token saw, stemming might return just s, whereas lemmatization would attempt to return either see or saw depending on whether the use of the token was as a verb or a noun. The two may also differ in that stemming most commonly collapses derivationally related words, whereas lemmatization commonly only collapses the different inflectional forms of a lemma. Linguistic processing for stemming or lemmatization is often done by an additional plug-in component to the indexing process, and a number of such components exist, both commercial and open-source. [Source: Stanford NLP Group](https://nlp.stanford.edu/IR-book/html/htmledition/stemming-and-lemmatization-1.html)
#
# TextaCy provides a `lemma_` attribute for `token` object for exactly this purpose.

# %%
for t in my_doc.tokens:
    print(t,t.lemma_)
# Out:
# Mr. mr.
# Speaker speaker
# , ,
# I -PRON-
# was be
# unavoidably unavoidably
# absent absent
# during during
# the the
# votes vote
# on on
# default default
# legislation legislation
# . .
# If if
# I -PRON-
# had have
# been be
# present present
# , ,
# I -PRON-
# would would
# have have
# voted vote
# " "
# nay nay
# " "
# on on
# the the
# motions motion
# to to
# table table
# the the
# appeal appeal
# of of
# the the
# ruling ruling
# of of
# the the
# Chair chair
# with with
# regards regard
# to to
# the the
# resolutions resolution
# offered offer
# by by
# Mr. mr.
# Gephardt gephardt
# ( (
# rollcall rollcall
# No no
# . .
# 26 26
# ) )
# and and
# Ms. ms.
# Jackson jackson
# - -
# Lee lee
# ( (
# rollcall rollcall
# No no
# . .
# 27 27
# ) )
# , ,
# I -PRON-
# would would
# have have
# voted vote
# " "
# nay nay
# " "
# on on
# the the
# ordering ordering
# of of
# the the
# previous previous
# question question
# on on
# House house
# Resolution resolution
# 355 355
# ( (
# rollcall rollcall
# No no
# . .
# 28 28
# ) )
# . .
# I -PRON-
# would would
# have have
# voted vote
# " "
# nay nay
# " "
# on on
# H. h.
# Con con
# . .
# Res res
# . .
# 141 141
# ( (
# rollcall rollcall
# No no
# . .
# 29 29
# ) )
# . .
# I -PRON-
# would would
# have have
# voted vote
# " "
# yea yea
# " "
# on on
# H.R. h.r.
# 2924 2924
# ( (
# rollcall rollcall
# No no
# . .
# 30 30
# ) )
# . .

# %% [markdown]
# # Exercise
#
# In this exercise, you are going to complete following tasks.
# 1. From the `corpus` variable, generate a new list named `jb_lst` that contains all speeches from `Joseph Biden`. (__HINT__: use similar code as we filter `cw` for 'Bernie Sanders'.)
# 2. Select first 5 speeches (`doc`) from `jb_lst` and store them in a new list named `jb_selected`.
# 3. For each element in `jb_selected`, print out:
#     a. Named Entities (`named_entities()`)
#     b. Text Statistics (`TextStats()`)
# 4. For each element in `jb_selected`, print out the top 20 words based on their tf-idf score.
# 5. For each element in `jb_selected`, print out __lemmas__ (`lemma_`) for each token if it is not a stop word (`is_stop`) and is a word token (`is_alpha`).

# %%
#### Complete your code here

jb_lst = []
match_func = lambda doc: doc.metadata.get("speaker_name") == "Joseph Biden"
for doc in corpus.get(match_func):
    jb_lst.append(doc)
    
jb_selected = jb_lst[:5]
for word in range(0, len(jb_selected)):
    #3
    print(list(textacy.extract.named_entities(jb_selected[word])), '\n')
    
    stats = textacy.TextStats(jb_selected[word])
    print((stats.basic_counts), '\n')
    
    #4
    corpus2 = textacy.Corpus('en', texts=str(jb_selected[word]))
    counts2 = corpus2.word_freqs(weighting='count', as_strings=True)
    idf2 = corpus2.word_doc_freqs(as_strings=True, weighting='idf')
    tf_idf2 = {k: counts2[k]/idf2[k] for k in idf2.keys() & counts}
    print(sorted(tf_idf2.items(), key=lambda x: x[1], reverse=True)[:20])
    
    #5
    for t in jb_selected[word].tokens:
        if ((t.is_stop == False) and (t.is_alpha)):
            print(t.lemma_, t.is_stop)
# Out:
# [today, tens of thousands, American, hundreds of millions, American, February 19, Russian Government, American, Russia, next few weeks, American, Russia, more than $700 million, over 20 percent, American, Russia, Delmarva Peninsula, 21,000 poultry, more than 600 million, Russian, Last summer, Allen, Family Food, Seaford, DE, 1,300 tons, Russia, one, Delaware, Port of Wilmington, Delaware, Russian, Russian, Manor Farms, Allen's Foods, Delaware, 100 percent, Russia, American, day, recent years, Russia, Moscow, St. Petersburg, America, America, Russia, Russian, Russian, Russian, Russian, American, Delaware, Russian, Now, American, Russian, Russian, United States, Soviet Union, election year, Russian Government's, American, Agriculture, Dan Glickman, Russian Government, United States, IMF, Russia, $10.2 billion, Communist, Russians, Russians, monthly, 3 years, Russian, Russia, World Trade Organization and America, WTO, United States, WTO, Russia, Russians, American, WTO, up to a year, Clinton, Russians, Russian Government]
#
# {'n_sents': 47, 'n_words': 1067, 'n_chars': 5123, 'n_syllables': 1643, 'n_unique_words': 449, 'n_long_words': 285, 'n_monosyllable_words': 702, 'n_polysyllable_words': 153}
#
# [('1', 0.5581106265512472), ('0', 0.23459420572161058), ('-PRON-', 0.23459420572161058), ('2', 0.23459420572161058)]
# president False
# -PRON- False
# rise False
# today False
# address False
# recent False
# trade False
# dispute False
# threaten False
# ten False
# thousand False
# american False
# job False
# hundred False
# million False
# american False
# export False
# on False
# february False
# russian False
# government False
# notify False
# soon False
# stop False
# import False
# poultry False
# product False
# complaint False
# american False
# food False
# safety False
# standard False
# meet False
# on False
# little False
# enter False
# russia False
# week False
# subject False
# sharp False
# increase False
# tax False
# import False
# poultry False
# american False
# poultry False
# export False
# russia False
# large False
# poultry False
# export False
# customer False
# total False
# million False
# year False
# represent False
# percent False
# explain False
# elimination False
# major False
# foreign False
# competitor False
# fit False
# election False
# year False
# agricultural False
# policy False
# but False
# excuse False
# russian False
# government False
# action False
# american False
# poultry False
# producer False
# -PRON- False
# allow False
# decision False
# stand False
# -PRON- False
# speak False
# agriculture False
# secretary False
# dan False
# glickman False
# directly False
# -PRON- False
# applaud False
# effort False
# negotiating False
# team False
# resolve False
# dispute False
# the False
# russian False
# government False
# understand False
# step False
# united False
# states False
# poultry False
# industry False
# step False
# away False
# international False
# economic False
# community False
# tell False
# eager False
# join False
# the False
# imf False
# announce False
# loan False
# russia False
# worth False
# billion False
# this False
# money False
# intend False
# smooth False
# transition False
# old False
# communist False
# command False
# economy False
# efficient False
# open False
# market False
# economy False
# the False
# term False
# loan False
# include False
# requirement False
# russians False
# continue False
# reform False
# economy False
# and False
# russians False
# aware False
# term False
# loan False
# provide False
# monthly False
# installment False
# year False
# evidence False
# backsliding False
# renege False
# commitment False
# open False
# russian False
# economy False
# ground False
# terminate False
# loan False
# point False
# russia False
# tell False
# want False
# join False
# world False
# trade False
# organization False
# america False
# support False
# application False
# join False
# wto False
# as False
# matter False
# fact False
# right False
# united False
# states False
# representative False
# wto False
# working False
# group False
# approve False
# russia False
# trade False
# practice False
# -PRON- False
# representative False
# crystal False
# clear False
# russians False
# action False
# like False
# bogus False
# ban False
# american False
# poultry False
# import False
# violate False
# spirit False
# letter False
# international False
# agreement False
# wto False
# -PRON- False
# imagine False
# want False
# stain False
# record False
# come False
# argue False
# ready False
# undertake False
# responsibility False
# participation False
# international False
# trading False
# system False
# but False
# review False
# process False
# year False
# -PRON- False
# ask False
# president False
# clinton False
# appoint False
# interagency False
# work False
# group False
# investigate False
# immediate False
# retaliatory False
# trade False
# action False
# russians False
# -PRON- False
# sincerely False
# hope False
# retaliation False
# necessary False
# convince False
# russian False
# government False
# turn False
# course False
# announce False
# [week, United States, year, U.S., U.S., U.S., U.S., hundreds of tons, American, American, America, U.S.
# , America, United States, Latin America, America, Colombia, United States, Colombia, Colombian, Mexico, U.S., last year, Colombia, Mexican, Colombia, Colombian, National Police, Serrano, Hundreds, Colombians, last year, Government, Colombia, Ernesto Samper, $6 million, Cali, at least 20, years, 1989, Bush, Bahamas, Bahamas, Government, Colombia, Senate, first, Samper, Cali, summer of 1994, U.S., Samper, House of Representatives, Samper, August 1994, United States, Colombia, Samper, Last year's, Colombia, first, United States, Colombia, Colombian, DEA, six, Cali, just last month, one, Colombian, 24 percent, last year, Colombian, America, coming year, Colombian Government, United States, Foreign Assistance Act, Colombia, Mexico, Colombia, Mexican, United States, Mexico, Mexico, year, Mexico, last year, Colombia, Mexico, Caribbean, Mexico, Mexican, Mexican, Colombian, Mexican, United States, more than two-thirds, Mexico, Mexican, Mexican, one, Mexico, Last year, Mexico, $10 million, hundreds of millions of dollars, Mexico, Mexico, Zedillo, Juan Abrego — leader, Mexican, United States, Mexican, Mexico, Mexico, Mexico, Mexico, Mexican, United States, Mexico, Last year, Colombian, year, Mexican, Mexico, Mexico, Mexican, 1993, North American Free Trade Agreement —, Mexico, last year, Clinton, Mexico, Mexico, NAFTA, Mexican, Colombia, Mexico, Colombia, United States]
# stay False
# path False
# choose False
# [Hatch, Shelby, Grassley, $3.9 million, Drug, — General, McCaffrey — with, Office of National Drug Control Policy, more than a decade, Reagan, 1988, Drug Office, first, Drug Office, Cabinet, today, Drug, General, additional $3.9 million, 80, Today, Republican, McCaffrey, Republican, McCaffrey]
#
# {'n_sents': 14, 'n_words': 266, 'n_chars': 1286, 'n_syllables': 422, 'n_unique_words': 142, 'n_long_words': 73, 'n_monosyllable_words': 165, 'n_polysyllable_words': 45}
#
# [('8', 0.23537745555238682), ('-PRON-', 0.23537745555238682), ('9', 0.23537745555238682), ('2', 0.23537745555238682)]
# president False
# -PRON- False
# support False
# amendment False
# offer False
# senators False
# hatch False
# shelby False
# grassley False
# drug False
# office False
# -PRON- False
# strongly False
# support False
# addition False
# million False
# help False
# new False
# drug False
# director False
# general False
# mccaffrey False
# increase False
# staff False
# need False
# as False
# colleague False
# know False
# -PRON- False
# distinction False
# author False
# law False
# open False
# office False
# national False
# drug False
# control False
# policy False
# -PRON- False
# take False
# decade False
# worth False
# effort False
# start False
# office False
# reagan False
# administration False
# oppose False
# effort False
# drug False
# director False
# -PRON- False
# finally False
# relent False
# let False
# offer False
# little False
# history False
# drug False
# office False
# staff False
# reduce False
# place False
# under False
# previous False
# administration False
# drug False
# office False
# overrun False
# political False
# appointee False
# frankly False
# political False
# dumping False
# ground False
# great False
# percentage False
# political False
# appointee False
# cabinet False
# agency False
# this False
# reason False
# reduction False
# staff False
# key False
# reason False
# -PRON- False
# oppose False
# reduction False
# but False
# today False
# new False
# drug False
# director False
# accomplished False
# impressive False
# general False
# task False
# difficult False
# job False
# bring False
# action False
# national False
# effort False
# drug False
# the False
# general False
# ask False
# president False
# formally False
# request False
# additional False
# million False
# increase False
# staff False
# personnel False
# today False
# offer False
# amendment False
# sponsor False
# republican False
# senator False
# provide False
# general False
# mccaffrey False
# request False
# -PRON- False
# hope False
# signal False
# republican False
# colleague False
# supportive False
# general False
# mccaffrey False
# future False
# request False
# [today, January of this year, State, Delaware, one, today, Delaware, Delaware, first, State, Constitution, Delaware, one, Senate, today, today, two, 4.25, 5.15, Delaware, two, 4.25, 5.00, State, 30,000, Delawareans, 9.5 percent, 11.5 percent, Delaware, today, 1991, Bush, nearly 50 cents, 40-year, year, full 40-hour workweek, 52 weeks, just $8,840, three-quarters, three, American, 5 percent, year, 1979, about 2.5 percent, same time.
# , Between 1977 and 1992, 20 percent, American, 17 percent, 20 percent, 28-percent, 1 percent, 91 percent, Now, last 20 to 25 years, 1 percent, Nation, America, World War
# , American, Americans, Americans, Americans, America, end of the day, century, today, Delaware, America]
#
# {'n_sents': 49, 'n_words': 1207, 'n_chars': 5364, 'n_syllables': 1739, 'n_unique_words': 433, 'n_long_words': 267, 'n_monosyllable_words': 848, 'n_polysyllable_words': 144}
#
# [('-PRON-', 0.23459420572161058), ('7', 0.23459420572161058), ('b', 0.23459420572161058), ('5', 0.23459420572161058), ('1', 0.23459420572161058), ('3', 0.23459420572161058)]
# president False
# -PRON- False
# come False
# debate False
# minimum False
# wage False
# different False
# perspective False
# reach False
# simple False
# business False
# cycle False
# see False
# couple False
# time False
# nation False
# economic False
# history False
# there False
# lot False
# evidence False
# economy False
# longer False
# function False
# way False
# longer False
# provide False
# stable False
# middle False
# income False
# job False
# build False
# america False
# middle False
# class False
# world False
# war False
# as False
# faith False
# free False
# enterprise False
# system False
# president False
# -PRON- False
# inclined False
# change False
# way False
# system False
# work False
# change False
# market False
# change False
# product False
# change False
# skill False
# key False
# feature False
# american False
# economy False
# but False
# americans False
# strong False
# tolerance False
# appetite False
# dynamic False
# shift False
# characterize False
# economic False
# system False
# equally False
# strong False
# sense False
# fairness False
# americans False
# expect False
# hard False
# work False
# reward False
# rich False
# maybe False
# certainly False
# little False
# security False
# little False
# comfort False
# for False
# far False
# americans False
# president False
# system False
# provide False
# far False
# dynamic False
# change False
# far False
# little False
# fairness False
# -PRON- False
# want False
# colleague False
# forget False
# absolute False
# bedrock False
# requirement False
# democratic False
# system False
# belief False
# majority False
# people False
# treat False
# fairly False
# because False
# free False
# enterprise False
# economy False
# president False
# america False
# -PRON- False
# bless False
# system False
# popular False
# government False
# provide False
# protect False
# property False
# right False
# foundation False
# economy False
# take False
# away False
# sense False
# fairness False
# away False
# sense False
# end False
# day False
# justice False
# way False
# capitalist False
# democracy False
# work False
# people False
# start False
# look False
# system False
# answer False
# the False
# unhappy False
# history False
# century False
# provide False
# example False
# blithely False
# dismiss False
# problem False
# -PRON- False
# real False
# line False
# eye False
# balance False
# sheet False
# fairness False
# no False
# national False
# wealth False
# buy False
# sense False
# fairness False
# list False
# statistic False
# substitute False
# as False
# optimist False
# president False
# -PRON- False
# believe False
# face False
# insurmountable False
# crisis False
# in False
# fact False
# reading False
# large False
# history False
# pretty False
# successful False
# search False
# way False
# balance False
# change False
# demand False
# dynamic False
# economy False
# unchanging False
# demand False
# basic False
# fairness False
# simple False
# justice False
# way False
# reward False
# work False
# -PRON- False
# work False
# pay False
# work False
# realistic False
# alternative False
# wasteful False
# choice False
# welfare False
# crime False
# surely False
# cost False
# modest False
# minimum False
# wage False
# bill False
# today False
# so False
# -PRON- False
# urge False
# colleague False
# follow False
# lead False
# state False
# delaware False
# restore False
# historical False
# value False
# minimum False
# wage False
# justice False
# real False
# line False
# america False

# %%
#### Complete your code here

jb_lst = []
match_func = lambda doc: doc.metadata.get("speaker_name") == "Joseph Biden"
for doc in corpus.get(match_func):
    jb_lst.append(doc)
    
jb_selected = jb_lst[:5]
for word in jb_selected:
    print(list(textacy.extract.named_entities(word)), '\n')
    stats = textacy.TextStats(word)
    print((stats.basic_counts), '\n')
    #idf = word.word_doc_counts(as_strings=True, weighting='idf')
    #print(sorted(tf_idf.items(), key=lambda x: x[1], reverse=True)[:20])
    for t in word.tokens:
        if ((t.is_stop == False) and (t.is_alpha)):
            print(t.lemma_, t.is_stop)
# Out:
# [today, tens of thousands, American, hundreds of millions, American, February 19, Russian Government, American, Russia, next few weeks, American, Russia, more than $700 million, over 20 percent, American, Russia, Delmarva Peninsula, 21,000 poultry, more than 600 million, Russian, Last summer, Allen, Family Food, Seaford, DE, 1,300 tons, Russia, one, Delaware, Port of Wilmington, Delaware, Russian, Russian, Manor Farms, Allen's Foods, Delaware, 100 percent, Russia, American, day, recent years, Russia, Moscow, St. Petersburg, America, America, Russia, Russian, Russian, Russian, Russian, American, Delaware, Russian, Now, American, Russian, Russian, United States, Soviet Union, election year, Russian Government's, American, Agriculture, Dan Glickman, Russian Government, United States, IMF, Russia, $10.2 billion, Communist, Russians, Russians, monthly, 3 years, Russian, Russia, World Trade Organization and America, WTO, United States, WTO, Russia, Russians, American, WTO, up to a year, Clinton, Russians, Russian Government]
#
# {'n_sents': 47, 'n_words': 1067, 'n_chars': 5123, 'n_syllables': 1643, 'n_unique_words': 449, 'n_long_words': 285, 'n_monosyllable_words': 702, 'n_polysyllable_words': 153}
#
# president False
# -PRON- False
# rise False
# today False
# address False
# recent False
# trade False
# dispute False
# threaten False
# ten False
# thousand False
# american False
# job False
# hundred False
# million False
# american False
# export False
# on False
# february False
# russian False
# government False
# notify False
# soon False
# stop False
# import False
# poultry False
# product False
# complaint False
# american False
# food False
# safety False
# standard False
# meet False
# on False
# little False
# enter False
# russia False
# week False
# subject False
# sharp False
# increase False
# tax False
# import False
# poultry False
# american False
# poultry False
# export False
# russia False
# large False
# poultry False
# export False
# customer False
# total False
# million False
# year False
# represent False
# percent False
# american False
# export False
# russia False
# president False
# delmarva False
# peninsula False
# home False
# poultry False
# worker False
# produce False
# million False
# bird False
# year False
# major False
# supplier False
# russian False
# poultry False
# market False
# last False
# summer False
# example False
# allen False
# family False
# food False
# seaford False
# de False
# export False
# ton False
# frozen False
# poultry False
# russia False
# at False
# time False
# -PRON- False
# probably False
# meet False
# poultry False
# grower False
# processor False
# state False
# delaware False
# -PRON- False
# see False
# step False
# process False
# poultry False
# house False
# packaging False
# plant False
# freezer False
# port False
# wilmington False
# -PRON- False
# delaware False
# poultry False
# industry False
# foreign False
# domestic False
# challenger False
# term False
# sanitary False
# standard False
# particularly False
# russian False
# plant False
# but False
# team False
# russian False
# inspector False
# come False
# country False
# poultry False
# processing False
# facility False
# include False
# plant False
# manor False
# farms False
# allen False
# food False
# state False
# delaware False
# fail False
# operation False
# literally False
# percent False
# failure False
# rate False
# -PRON- False
# find False
# simply False
# unbelievable False
# this False
# tell False
# real False
# agenda False
# health False
# safety False
# -PRON- False
# demand False
# standard False
# poultry False
# ship False
# russia False
# poultry False
# show False
# american False
# supermarket False
# kitchen False
# table False
# day False
# that False
# recent False
# year False
# russia False
# consumer False
# particularly False
# great False
# urban False
# center False
# moscow False
# petersburg False
# buy False
# poultry False
# product False
# america False
# -PRON- False
# recognize False
# good False
# value False
# -PRON- False
# produce False
# better False
# tasting False
# nutritious False
# expensive False
# poultry False
# america False
# ship False
# russia False
# low False
# price False
# current False
# russian False
# poultry False
# industry False
# -PRON- False
# struggle False
# inefficiency False
# old False
# economic False
# system False
# if False
# ban False
# go False
# effect False
# president False
# russian False
# people False
# lose False
# major False
# high False
# quality False
# supplier False
# popular False
# staple False
# diet False
# food False
# bill False
# the False
# thing False
# russian False
# economy False
# need False
# -PRON- False
# sincerely False
# hope False
# retaliation False
# necessary False
# convince False
# russian False
# government False
# turn False
# course False
# announce False
# [week, United States, year, U.S., U.S., U.S., U.S., hundreds of tons, American, American, America, U.S.
# , America, United States, Latin America, America, Colombia, United States, Colombia, Colombian, Mexico, U.S., last year, Colombia, Mexican, Colombia, Colombian, National Police, Serrano, Hundreds, Colombians, last year, Government, Colombia, Ernesto Samper, $6 million, Cali, at least 20, years, 1989, Bush, Bahamas, Bahamas, Government, Colombia, Senate, first, Samper, Cali, summer of 1994, U.S., Samper, House of Representatives, Samper, August 1994, United States, Colombia, Samper, Last year's, Colombia, first, United States, Colombia, Colombian, DEA, six, Cali, just last month, one, Colombian, 24 percent, last year, Colombian, America, coming year, Colombian Government, United States, Foreign Assistance Act, Colombia, Mexico, Colombia, Mexican, United States, Mexico, Mexico, year, Mexico, last year, Colombia, Mexico, Caribbean, Mexico, Mexican, Mexican, Colombian, Mexican, United States, more than two-thirds, Mexico, Mexican, Mexican, one, Mexico, Last year, Mexico, $10 million, hundreds of millions of dollars, Mexico, Mexico, Zedillo, Juan Abrego — leader, Mexican, United States, Mexican, Mexico, Mexico, Mexico, Mexico, Mexican, United States, Mexico, Last year, Colombian, year, Mexican, Mexico, Mexico, Mexican, 1993, North American Free Trade Agreement —, Mexico, last year, Clinton, Mexico, Mexico, NAFTA, Mexican, Colombia, Mexico, Colombia, United States]
#
# {'n_sents': 104, 'n_words': 2260, 'n_chars': 11081, 'n_syllables': 3548, 'n_unique_words': 712, 'n_long_words': 621, 'n_monosyllable_words': 1476, 'n_polysyllable_words': 361}
#
# president False
# -PRON- False
# rise False
# draw False
# line False
# line False
# divide False
# nation False
# country False
# fall False
# prey False
# obscene False
# influence False
# international False
# drug False
# cartel False
# this False
# week False
# president False
# offer False
# decision False
# draw False
# line False
# country False
# cooperate False
# sufficiently False
# united False
# states False
# counter False
# narcotic False
# effort False
# justify False
# benefit False
# partnership False
# nation False
# this False
# year False
# neighbor False
# cross False
# line False
# certify False
# fully False
# cooperate False
# drug False
# enforcement False
# effort False
# other False
# neighbor False
# come False
# perilously False
# close False
# cross False
# line False
# before False
# offer False
# specific False
# view False
# country False
# -PRON- False
# believe False
# cross False
# line False
# -PRON- False
# want False
# offer False
# general False
# view False
# drug False
# certification False
# process False
# foremost False
# certification False
# process False
# seek False
# shift False
# blame False
# drug False
# scourge False
# solely False
# drug False
# produce False
# transit False
# country False
# in False
# fact False
# comprehensive False
# drug False
# strategy False
# -PRON- False
# offer False
# government False
# people False
# remain False
# vigilant False
# committed False
# attack False
# drug False
# problem False
# home False
# but False
# -PRON- False
# recognize False
# slow False
# flow False
# drug False
# integral False
# comprehensive False
# drug False
# strategy False
# and False
# effort False
# cut False
# literally False
# hundred False
# ton False
# drug False
# flow False
# american False
# shore False
# assist False
# country False
# continue False
# partner False
# family False
# nation False
# president False
# let False
# real False
# simple False
# nation False
# wish False
# enjoy False
# benefit False
# american False
# friendship False
# help False
# america False
# fight False
# scourge False
# drug False
# this False
# impossible False
# task False
# -PRON- False
# [today, January of this year, State, Delaware, one, today, Delaware, Delaware, first, State, Constitution, Delaware, one, Senate, today, today, two, 4.25, 5.15, Delaware, two, 4.25, 5.00, State, 30,000, Delawareans, 9.5 percent, 11.5 percent, Delaware, today, 1991, Bush, nearly 50 cents, 40-year, year, full 40-hour workweek, 52 weeks, just $8,840, three-quarters, three, American, 5 percent, year, 1979, about 2.5 percent, same time.
# , Between 1977 and 1992, 20 percent, American, 17 percent, 20 percent, 28-percent, 1 percent, 91 percent, Now, last 20 to 25 years, 1 percent, Nation, America, World War
# , American, Americans, Americans, Americans, America, end of the day, century, today, Delaware, America]
#
# {'n_sents': 49, 'n_words': 1207, 'n_chars': 5364, 'n_syllables': 1739, 'n_unique_words': 433, 'n_long_words': 267, 'n_monosyllable_words': 848, 'n_polysyllable_words': 144}
#
# president False
# -PRON- False
# come False
# debate False
# minimum False
# wage False
# different False
# perspective False
# colleague False
# today False
# in False
# january False
# year False
# state False
# delaware False
# decide False
# raise False
# minimum False
# wage False
# debate False
# lot False
# like False
# hear False
# today False
# -PRON- False
# like False
# think False
# delaware False
# special False
# place False
# president False
# way False
# but False
# lot False
# like False
# rest False
# country False
# -PRON- False
# big False
# business False
# small False
# world False
# class False
# high False
# technology False
# business False
# chemical False
# pharmaceutical False
# cutting False
# edge False
# financial False
# service False
# sector False
# lot False
# colleague False
# surprised False
# -PRON- False
# tell False
# major False
# agricultural False
# sector False
# with False
# kind False
# diversity False
# -PRON- False
# think False
# delaware False
# teach False
# rest False
# country False
# -PRON- False
# state False
# ratify False
# constitution False
# think False
# example False
# worth False
# follow False
# the False
# proposal False
# adopt False
# delaware False
# like False
# senate False
# today False
# the False
# proposal False
# today False
# step False
# increase False
# minimum False
# wage False
# current False
# hour False
# in False
# delaware False
# choose False
# step False
# increase False
# in False
# state False
# increase False
# directly False
# affect False
# delawareans False
# family False
# percent False
# work False
# force False
# little False
# national False
# average False
# percent False
# currently False
# work False
# minimum False
# wage False
# so False
# delaware False
# like False
# rest False
# country False
# president False
# little False
# bit False
# ahead False
# everybody False
# come False
# address False
# problem False
# stagnant False
# family False
# income False
# general False
# shrink False
# value False
# minimum False
# wage False
# particular False
# and False
# -PRON- False
# like False
# talk False
# today False
# president False
# puzzle False
# grow False
# economy False
# rise False
# productivity False
# rise False
# profit False
# time False
# job False
# hard False
# work False
# adult False
# fail False
# provide False
# rise False
# standard False
# living False
# the False
# minimum False
# wage False
# provide False
# important False
# illustration False
# disturb False
# trend False
# since False
# time False
# raise False
# minimum False
# wage False
# bipartisan False
# majority False
# president False
# sign False
# law False
# president False
# bush False
# real False
# spending False
# power False
# minimum False
# wage False
# drop False
# nearly False
# cent False
# if False
# fail False
# raise False
# minimum False
# wage False
# drop False
# low False
# year False
# right False
# workweek False
# week False
# year False
# home False
# quarter False
# poverty False
# level False
# family False
# for False
# family False
# time False
# worker False
# current False
# minimum False
# wage False
# minimum False
# need False
# stay False
# poverty False
# that False
# forget False
# search False
# way False
# convince False
# people False
# stay False
# welfare False
# turn False
# away False
# crime False
# there False
# unfortunately False
# example False
# decline False
# reward False
# hard False
# work False
# american False
# family False
# -PRON- False
# wage False
# earner False
# work False
# family False
# poverty False
# see False
# income False
# stick False
